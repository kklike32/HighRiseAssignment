# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import os

# %%
BASE_URL = "https://support.highrise.game/en/"

# %%
response = requests.get(BASE_URL)
if response.status_code == 200:
    main_page_html = response.text
else:
    print(f"Failed to retrieve the main page. Status code: {response.status_code}")

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(main_page_html, 'lxml')

# Find all category links
category_links = soup.find_all('a', {'data-testid': 'collection-card-compact'})
categories = []

for link in category_links:
    category_name_div = link.find('div', {'data-testid': 'collection-name'})
    if category_name_div:
        category_name = category_name_div.get_text(strip=True)
    else:
        category_name = 'Unknown Category'
    category_url = link['href']
    categories.append({
        'name': category_name,
        'url': category_url
    })

# Check the categories extracted
print(f"Found {len(categories)} categories.")
for cat in categories:
    print(cat['name'], cat['url'])
# Out:
# Found 20 categories.
# 4.0 Features https://support.highrise.game/en/collections/8183635-4-0-features
# What's Highrise about? https://support.highrise.game/en/collections/4710659-what-s-highrise-about
# Gold, Bubbles and Payments https://support.highrise.game/en/collections/4710692-gold-bubbles-and-payments
# Newsfeed and Posting https://support.highrise.game/en/collections/4711623-newsfeed-and-posting
# Rooms and Building https://support.highrise.game/en/collections/4711832-rooms-and-building
# Rewards and Gifts https://support.highrise.game/en/collections/4712644-rewards-and-gifts
# Grabs and Shop Items https://support.highrise.game/en/collections/4712950-grabs-and-shop-items
# Reporting https://support.highrise.game/en/collections/6037541-reporting
# Your Crew https://support.highrise.game/en/collections/6121827-your-crew
# Trading and Selling Items https://support.highrise.game/en/collections/6121878-trading-and-selling-items
# Bugs and Troubleshooting https://support.highrise.game/en/collections/6121903-bugs-and-troubleshooting
# Account Settings and Security https://support.highrise.game/en/collections/6121909-account-settings-and-security
# Highrise Competitions & Rules https://support.highrise.game/en/collections/6121965-highrise-competitions-rules
# SkyRise Mall https://support.highrise.game/en/collections/6121999-skyrise-mall
# Official Discord Sever Information https://support.highrise.game/en/collections/6122006-official-discord-sever-information
# Highrise Creators https://support.highrise.game/en/collections/6122012-highrise-creators
# Highrise Concepts https://support.highrise.game/en/collections/6122015-highrise-concepts
# Events https://support.highrise.game/en/collections/8171841-events
# Creature Club https://support.highrise.game/en/collections/8631632-creature-club
# Highrise LAND https://support.highrise.game/en/collections/8631690-highrise-land

# %%
all_articles = []

for category in categories:
    print(f"Processing category: {category['name']}")
    category_url = category['url']
    
    # Fetch category page
    response = requests.get(category_url)
    if response.status_code != 200:
        print(f"Failed to retrieve category page: {category_url}")
        continue
    soup = BeautifulSoup(response.text, 'lxml')
    
    # Find all article links
    article_links = soup.find_all('a', {'data-testid': 'article-link'})
    articles = []
    
    for link in article_links:
        article_title_span = link.find('span', {'class': 'm-0 text-md text-body-primary-color group-hover/article:text-primary font-regular'})
        if article_title_span:
            article_title = article_title_span.get_text(strip=True)
        else:
            article_title = 'Unknown Article'
        article_url = link['href']
        articles.append({
            'title': article_title,
            'url': article_url,
            'category': category['name']
        })
    
    print(f"Found {len(articles)} articles in category '{category['name']}'.")
    all_articles.extend(articles)
    time.sleep(1) 

print(f"Total articles found: {len(all_articles)}")
# Out:
# Processing category: 4.0 Features
# Found 14 articles in category '4.0 Features'.
# Processing category: What's Highrise about?
# Found 3 articles in category 'What's Highrise about?'.
# Processing category: Gold, Bubbles and Payments
# Found 12 articles in category 'Gold, Bubbles and Payments'.
# Processing category: Newsfeed and Posting
# Found 5 articles in category 'Newsfeed and Posting'.
# Processing category: Rooms and Building
# Found 15 articles in category 'Rooms and Building'.
# Processing category: Rewards and Gifts
# Found 5 articles in category 'Rewards and Gifts'.
# Processing category: Grabs and Shop Items
# Found 9 articles in category 'Grabs and Shop Items'.
# Processing category: Reporting
# Found 4 articles in category 'Reporting'.
# Processing category: Your Crew
# Found 8 articles in category 'Your Crew'.
# Processing category: Trading and Selling Items
# Found 4 articles in category 'Trading and Selling Items'.
# Processing category: Bugs and Troubleshooting
# Found 3 articles in category 'Bugs and Troubleshooting'.
# Processing category: Account Settings and Security
# Found 10 articles in category 'Account Settings and Security'.
# Processing category: Highrise Competitions & Rules
# Found 6 articles in category 'Highrise Competitions & Rules'.
# Processing category: SkyRise Mall
# Found 3 articles in category 'SkyRise Mall'.
# Processing category: Official Discord Sever Information
# Found 3 articles in category 'Official Discord Sever Information'.
# Processing category: Highrise Creators
# Found 4 articles in category 'Highrise Creators'.
# Processing category: Highrise Concepts
# Found 6 articles in category 'Highrise Concepts'.
# Processing category: Events
# Found 4 articles in category 'Events'.
# Processing category: Creature Club
# Found 9 articles in category 'Creature Club'.
# Processing category: Highrise LAND
# Found 8 articles in category 'Highrise LAND'.
# Total articles found: 135

# %%
# Extract content from each article
for idx, article in enumerate(all_articles, start=1):
    print(f"Extracting article {idx}/{len(all_articles)}: {article['title']}")
    article_url = article['url']

    # Fetch article page
    response = requests.get(article_url)
    if response.status_code != 200:
        print(f"Failed to retrieve article page: {article_url}")
        continue
    soup = BeautifulSoup(response.text, 'lxml')

    # Extract the article content
    content_div = soup.find('div', class_='article_body')
    if content_div:
        # Remove the 'Related Articles' section
        related_section = content_div.find('section', class_='related_articles')
        if related_section:
            related_section.decompose()
        content = content_div.get_text(separator='\n', strip=True)
        article['content'] = content
    else:
        article['content'] = ''
        print(f"Content not found for article: {article['title']}")

    # Extract the last updated date 
    updated_div = soup.find('div', class_='avatar__info -mt-0.5 text-base')
    if updated_div:
        date_span = updated_div.find('span', class_='text-body-secondary-color')
        if date_span and 'Updated' in date_span.get_text():
            article['last_updated'] = date_span.get_text(strip=True)
        else:
            article['last_updated'] = ''
    else:
        article['last_updated'] = ''

    time.sleep(1)
# Out:
# Extracting article 1/135: 📌Pinning
# Extracting article 2/135: Deleting Items
# Extracting article 3/135: Profile 4.0
# Extracting article 4/135: How Do I Change My Background?
# Extracting article 5/135: What is Grab Swapping?
# Extracting article 6/135: Outfit of the Day
# Extracting article 7/135: Directory 4.0
# Extracting article 8/135: Social Media Links
# Extracting article 9/135: Highrise+
# Extracting article 10/135: Inbox Calls
# Extracting article 11/135: Inbox Optimizations
# Extracting article 12/135: Inbox Media Messages
# Extracting article 13/135: Engagement-Based Payouts
# Extracting article 14/135: Display Names
# Extracting article 15/135: What are the Highrise Community Guidelines?
# Extracting article 16/135: How do I play Highrise? What is this game about?
# Extracting article 17/135: How does the Highrise chat filter work?
# Extracting article 18/135: What are Bubbles?
# Extracting article 19/135: What is Gold and how do I get it?
# Extracting article 20/135: Why didn't I receive the gold that I purchased?
# Extracting article 21/135: Why was I double-charged? How do I deal with an accidental purchase?
# Extracting article 22/135: Why didn't I get my gold from a Sponsor's offer?
# Extracting article 23/135: Why are Gold Bars more expensive than Gold?
# Extracting article 24/135: How do sales work?
# Extracting article 25/135: How does Tipping work?
# Extracting article 26/135: What are Tip Jars?
# Extracting article 27/135: What's our Compensation Policy for In-Ad Appearances?
# Extracting article 28/135: What are Verified Resellers?
# Extracting article 29/135: What Is Earned Gold?
# Extracting article 30/135: How do I take screenshots in rooms?
# Extracting article 31/135: How Do I Create Photo, Video, and Text Posts?
# Extracting article 32/135: Why Was My Post Removed?
# Extracting article 33/135: How Do I Edit My Privacy & Newsfeed Settings?
# Extracting article 34/135: How Do I Delete a Post or Comment?
# Extracting article 35/135: Owned Room Subscriptions
# Extracting article 36/135: Owned Rooms
# Extracting article 37/135: How do I create a new room?
# Extracting article 38/135: How Do I Design My Room and Add More Furniture?
# Extracting article 39/135: Can I change my room size?
# Extracting article 40/135: Who Can Enter My Room? How Can I Change My Room’s Privacy Settings?
# Extracting article 41/135: How Do I Moderate My Room or Give Other Users Moderation Privileges?
# Extracting article 42/135: How Do I Collaborate With Others When Designing My Room?
# Extracting article 43/135: How Do I Add Music to My Room?
# Extracting article 44/135: How Do I Delete a Room?
# Extracting article 45/135: What Are Crew Rooms?
# Extracting article 46/135: What Are Room Boosts?
# Extracting article 47/135: What are Directory Categories?
# Extracting article 48/135: How do I use Voice Chat?
# Extracting article 49/135: What Is Spectating?
# Extracting article 50/135: What Is Skypass?
# Extracting article 51/135: Did Someone Say Free Gift Boxes?
# Extracting article 52/135: What are Crew Gifts?
# Extracting article 53/135: What Is the Lucky Wheel?
# Extracting article 54/135: How Do I Redeem a Promo Code?
# Extracting article 55/135: What Are Grabs and Spinning?
# Extracting article 56/135: Why Do Items Have Different Rarities?
# Extracting article 57/135: What Items Can I Buy in the Shop?
# Extracting article 58/135: Where do I buy furniture?
# Extracting article 59/135: Why Do Some Grabs Expire?
# Extracting article 60/135: What are the Reward Probabilities for Grabs owned by Highrise?
# Extracting article 61/135: What are Second-Hand Grabs?
# Extracting article 62/135: What Are Progress Rewards?
# Extracting article 63/135: What Are Grab Tokens?
# Extracting article 64/135: Keeping Highrise Safe: How to Report Community Guidelines Violations
# Extracting article 65/135: How do I appeal a mute, suspension, or ban?
# Extracting article 66/135: How do I kick or ban players from my room?
# Extracting article 67/135: How do I block someone?
# Extracting article 68/135: How do Crew Gifts work?
# Extracting article 69/135: Can I be in more than one crew?
# Extracting article 70/135: How do I add Admins to my Crew?
# Extracting article 71/135: Can I kick someone from my crew?
# Extracting article 72/135: What if I want to leave my crew?
# Extracting article 73/135: How do I make my own crew?
# Extracting article 74/135: How do I join a Crew?
# Extracting article 75/135: What's a crew?
# Extracting article 76/135: How do I trade?
# Extracting article 77/135: What are scams and how do I make sure I'm not scammed?
# Extracting article 78/135: Why did my items disappear after my trade was canceled?
# Extracting article 79/135: What is the Market?
# Extracting article 80/135: What should I do if my items are buggy?
# Extracting article 81/135: What if my phone died or crashed while I was spinning a Grab?
# Extracting article 82/135: Why are my items missing?
# Extracting article 83/135: Account Frozen for Being Underage
# Extracting article 84/135: Can I Delete My Account?
# Extracting article 85/135: What is Safety Lock?
# Extracting article 86/135: Staying safe on Highrise
# Extracting article 87/135: Can I sell, buy, or give away a Highrise account?
# Extracting article 88/135: How do I change my username?
# Extracting article 89/135: How do I register my email address?
# Extracting article 90/135: How do I connect my Highrise account to my Facebook, Google, or Snapchat account?
# Extracting article 91/135: How do I deal with scammers and hackers?
# Extracting article 92/135: What if I forgot my password?
# Extracting article 93/135: User Design Contest Feature (UDC)
# Extracting article 94/135: What Are"Inspired By" Item Attributions?
# Extracting article 95/135: What room and building competitions does Highrise host?
# Extracting article 96/135: What is the current avatar layering guide?
# Extracting article 97/135: Mini Design Contests
# Extracting article 98/135: Grab Design Contests: Rules and Guidelines
# Extracting article 99/135: What are special-token grabs? What is Heart Mart?
# Extracting article 100/135: What are Highrise house-made Brands?
# Extracting article 101/135: What is the SkyRise Mall?
# Extracting article 102/135: I receive an error when trying to verify my Highrise account on Discord
# Extracting article 103/135: How do I verify my account on Discord?
# Extracting article 104/135: How do I join the official Highrise Discord server?
# Extracting article 105/135: Are You Interested in Working With Us?
# Extracting article 106/135: Where can I find Highrise assets?
# Extracting article 107/135: What is HRLive and how do I apply?
# Extracting article 108/135: What's a Highrise bot and how do I get one?
# Extracting article 109/135: Tips, Tricks, and Other Questions
# Extracting article 110/135: Communicating with the Highrise Art Team
# Extracting article 111/135: How do I submit a Concept?
# Extracting article 112/135: How do I vote on Concepts?
# Extracting article 113/135: How do I access Highrise Concepts?
# Extracting article 114/135: What is Highrise Concepts?
# Extracting article 115/135: Highrise Events General FAQ
# Extracting article 116/135: Style Challenge Event Guide
# Extracting article 117/135: Prank Event Guide
# Extracting article 118/135: Donate Event Guide
# Extracting article 119/135: What are Creature Coins and how can I earn them?
# Extracting article 120/135: How do I purchase a Highrise Creature?
# Extracting article 121/135: I can’t afford a Highrise Creature, are there any other ways of getting one?
# Extracting article 122/135: How much does a Highrise Creature cost?
# Extracting article 123/135: What are the benefits and perks of owning a Highrise Creature?
# Extracting article 124/135: How do I become a member of the Highrise Creature Club?
# Extracting article 125/135: What are NFTs?
# Extracting article 126/135: What is the Highrise Creature Club?
# Extracting article 127/135: Highrise NFT Safety Tips
# Extracting article 128/135: I can't afford a Highrise LAND plot. Are there any other ways to own a plot of LAND?
# Extracting article 129/135: How do I become a Highrise LAND owner?
# Extracting article 130/135: What Are the Benefits of Owning Highrise LAND?
# Extracting article 131/135: How much does Highrise LAND cost?
# Extracting article 132/135: How to Purchase Highrise LAND
# Extracting article 133/135: How to create Estates
# Extracting article 134/135: How to add LAND Parcels Purchased with Promotional LAND Deeds onto the Blockchain
# Extracting article 135/135: What is Highrise LAND?

# %%
def clean_text(text):
    # Remove unwanted characters or patterns
    text = text.replace('\r', '').replace('\n', ' ').strip()
    return text

# Apply cleaning to article content
for article in all_articles:
    article['content'] = clean_text(article['content'])

# %%
os.makedirs('data', exist_ok=True)
with open('data/faq_data.json', 'w', encoding='utf-8') as f:
    json.dump(all_articles, f, ensure_ascii=False, indent=4)

print("Data extraction complete. Saved to data/faq_data.json")
# Out:
# Data extraction complete. Saved to data/faq_data.json
